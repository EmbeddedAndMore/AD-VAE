# %%
import os
import glob
from collections import defaultdict
import random
from abc import ABC, abstractmethod
import importlib
import functools
import time


import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from torch.nn import init
from torch.optim import lr_scheduler
from torch.utils.data import Dataset,DataLoader
import cv2 as cv
import imagesize
import torchvision.transforms as T
from PIL import Image
from joblib import Parallel, delayed
from tqdm.auto import tqdm

import utils
from dataset import TrashDataset

# %% [markdown]
# ### Adversary Variational AutoEncoder
# based on [this](https://github.com/CY-Jeong/anomaly-detection-mvtec)

# %%
def load_model(model_name):
    """import model using model name"""
    path = "models." + model_name
    model = importlib.import_module(path)
    model = model.__dict__[model_name.upper()]

    if model is None:
        print(" There is no model")
        exit(0)
    return model

def create_model(opt):
    """create model with model name"""
    model = load_model(opt.model)
    model = model(opt)
    print("model [%s] was created" % type(model).__name__)
    return model

def init_weights(net, init_type='normal', init_gain=0.02):
    """ define the initialization function and batchnorms"""
    def init_func(m):
        classname = m.__class__.__name__
        if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
            if init_type == 'normal':
                init.normal_(m.weight.data, 0.0, init_gain)
            elif init_type == 'xavier':
                init.xavier_normal_(m.weight.data, gain=init_gain)
            elif init_type == 'kaiming':
                init.kaiming_normal_(m.weight.data, a=0, mode='fan_in')
            elif init_type == 'orthogonal':
                init.orthogonal_(m.weight.data, gain=init_gain)
            else:
                raise NotImplementedError('initialization method [%s] is not implemented' % init_type)
            if hasattr(m, 'bias') and m.bias is not None:
                init.constant_(m.bias.data, 0.0)
        elif classname.find('BatchNorm2d') != -1:  # BatchNorm Layer's weight is not a matrix; only normal distribution applies.
            init.normal_(m.weight.data, 1.0, init_gain)
            init.constant_(m.bias.data, 0.0)

    print('initialize network with %s' % init_type)
    net.apply(init_func)  # apply the initialization function <init_func>

def init_net(net, init_type='normal', init_gain=0.02, gpu=[], mode='train'):
    """Initilaizing networks
    If # gpus is more than 1, we would be better to use dataparallel for keeping from memory shortage.
    And if this model is train mode, we need to initialize weights for rasing performance"""
    if len(gpu) > 0:
        assert(torch.cuda.is_available())
        net.to(gpu[0])
        net = nn.DataParallel(net, gpu)
    if mode == 'train':
        init_weights(net, init_type, init_gain=init_gain)
        return net

    return net

class Identity(nn.Module):
    def forward(self, x):
        return x

def get_norm_layer(norm_type='instance'):
    """Return a normalization layer

    Parameters:
        norm_type (str) -- the name of the normalization layer: batch | instance | none

    For BatchNorm, we use learnable affine parameters and track running statistics (mean/stddev).
    For InstanceNorm, we do not use learnable affine parameters. We do not track running statistics.
    """
    if norm_type == 'batch':
        norm_layer = functools.partial(nn.BatchNorm2d, affine=True, track_running_stats=True)
    elif norm_type == 'instance':
        norm_layer = functools.partial(nn.InstanceNorm2d, affine=False, track_running_stats=False)
    elif norm_type == 'none':
        def norm_layer(x): return Identity()
    else:
        raise NotImplementedError('normalization layer [%s] is not found' % norm_type)
    return norm_layer

def get_scheduler(optimizer, opt):
    if opt.lr_policy == 'linear':
        def lambda_rule(epoch):
            lr_l = 1.0 - max(0, epoch + opt.epoch_count - opt.n_epochs) / float(opt.n_epochs_decay)
            return lr_l
        scheduler = lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda_rule)
    elif opt.lr_policy == 'step':
        scheduler = lr_scheduler.StepLR(optimizer, step_size=opt.lr_decay_iters, gamma=0.1)
    elif opt.lr_policy == 'plateau':
        scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.2, threshold=0.01, patience=5)
    elif opt.lr_policy == 'cosine':
        scheduler = lr_scheduler.CosineAnnealingLR(optimizer, T_max=opt.n_epochs, eta_min=0)
    else:
        return NotImplementedError('learning rate policy [%s] is not implemented', opt.lr_policy)
    return scheduler

# %%
import torch.nn as nn
import torch

class Decoder(nn.Module):
    def __init__(self, img_shape, latent_dim):
        super().__init__()
        self.img_shape = img_shape
        self.model = nn.Sequential(
            # State (100x1x1)
            nn.ConvTranspose2d(in_channels=latent_dim, out_channels=1024, kernel_size=4, stride=1, padding=0),
            nn.BatchNorm2d(num_features=1024),
            nn.LeakyReLU(True),

            # State (1024x4x4)
            nn.ConvTranspose2d(in_channels=1024, out_channels=512, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(num_features=512),
            nn.LeakyReLU(True),

            # State (512x8x8)
            nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(num_features=256),
            nn.LeakyReLU(True),

            # State (256x16x16)
            nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(num_features=128),
            nn.LeakyReLU(True),

            # State (128x32x32)
            nn.ConvTranspose2d(in_channels=128, out_channels=64, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(num_features=64),
            nn.LeakyReLU(True),

            # State (64x64x64)
            nn.ConvTranspose2d(in_channels=64, out_channels=32, kernel_size=4, stride=2, padding=1),
            nn.BatchNorm2d(num_features=32),
            nn.LeakyReLU(True),

            # State (32x128x128)
            nn.ConvTranspose2d(in_channels=32, out_channels=3, kernel_size=4, stride=2, padding=1),
            nn.Tanh())

    def forward(self, input):
        img = self.model(input)
        return img.view(img.shape[0], *self.img_shape)


class Encoder(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()

        self.model = nn.Sequential(
            # State (3x256x256)
            nn.Conv2d(in_channels=3, out_channels=16, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(16, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # State (16x128x128)
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(32, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # State (32x64x64)
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(64, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # State (64x32x32)
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(128, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # State (128x16x16)
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(256, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # State (256x8x8)
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(512, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # State (512x4x4)
            nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=4, stride=1, padding=0)
            # output of main module --> State (1024x1x1)
        )

        self.last_layer = nn.Sequential(
            nn.Linear(1024, latent_dim),
            nn.Linear(latent_dim, latent_dim)
        )


    def forward(self, img):
        features = self.model(img)
        features = features.view(img.shape[0], -1)
        features = self.last_layer(features)
        features = features.view(features.shape[0], -1, 1, 1)
        return features
#------------------------------------------------------------------------------------------------------------

class Discriminator(nn.Module):
    def __init__(self, latent_dim):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(latent_dim, latent_dim),
            nn.Linear(latent_dim, 1),
            nn.Sigmoid()
        )

    def forward(self, feature):
        feature = feature.flatten(1)
        value = self.model(feature)
        return value

class Encoder_aae(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()

        self.model = nn.Sequential(
            # State (3x256x256)
            nn.Conv2d(in_channels=3, out_channels=16, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(16, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # State (16x128x128)
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(32, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # State (32x64x64)
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(64, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # State (64x32x32)
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(128, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # State (128x16x16)
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(256, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # State (256x8x8)
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(512, affine=True),
            nn.LeakyReLU(0.2, inplace=True),

            # State (512x4x4)
            nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=4, stride=1, padding=0)
            # output of main module --> State (1024x1x1)
        )

        self.last_layer = nn.Sequential(
            nn.Linear(1024, 512),
        )
        self.mu_layer = nn.Linear(512, latent_dim, bias=True)
        self.std_layer = nn.Linear(512, latent_dim, bias=True)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return eps.mul(std).add_(mu)

    def forward(self, img):
        z = self.model(img)
        features = z.view(img.shape[0], -1)
        features = self.last_layer(features)
        mu = self.mu_layer(features)
        logvar = self.mu_layer(features)
        z = self.reparameterize(mu, logvar)
        z = z.view(features.shape[0], -1, 1, 1)
        return z

# %%
class BaseModel(ABC):

    def __init__(self, opt):
        self.opt = opt
        self.gpu = opt.gpu
        self.device = torch.device(f'cuda:{self.gpu[0]}') if self.gpu else torch.device('cpu')
        self.optimizers = []
        self.networks = []
        self.save_dir = os.path.join(opt.save_dir, opt.object)
        if self.opt.mode == 'Train':
            self.isTrain = True
        elif self.opt.mode == 'Pretrained' or self.opt.mode == 'Test':
            self.isTrain = False
    @abstractmethod
    def set_input(self, input):
        pass

    @abstractmethod
    def train(self):
        pass
    @abstractmethod
    def test(self):
        pass

    def setup(self, opt):
        if opt.mode == 'train':
            self.schedulers = [get_scheduler(optimizer, opt) for optimizer in self.optimizers]
        elif opt.mode == 'test':
            self.load_networks()
        self.print_networks(opt.verbose)

    def set_requires_grad(self, *nets, requires_grad=False):
        for _, net in enumerate(nets):
            for param in net.parameters():
                param.requires_grad = requires_grad

    def get_generated_imags(self):
        visual_imgs = None
        for name in self.visual_names:
            if isinstance(name, str):
                visual_imgs = getattr(self, name)
        return visual_imgs

    def eval(self):
        for name in self.networks:
            net = getattr(self, name)
            net.eval()

    def update_learning_rate(self, epoch):
        old_lr = self.optimizers[0].param_groups[0]['lr']
        for scheduler in self.schedulers:
            if self.opt.lr_policy == 'plateau':
                scheduler.step(self.metric)
            else:
                scheduler.step()

        lr = self.optimizers[0].param_groups[0]['lr']
        print(f'{epoch} : learning rate {old_lr:.7f} -> {lr:.7f}')
    def print_networks(self, verbose):
        """Print the total number of parameters in the network and (if verbose) network architecture

        Parameters:
            verbose (bool) -- if verbose: print the network architecture
        """
        print('---------- Networks initialized -------------')
        for name in self.networks:
            if isinstance(name, str):
                net = getattr(self, name)
                num_params = 0
                for param in net.parameters():
                    num_params += param.numel()
                if verbose:
                    print(net)
                print('[Network %s] Total number of parameters : %.3f M' % (name, num_params / 1e6))
        print('-----------------------------------------------')

    def save_networks(self):
        utils.mkdirs(self.save_dir)
        save_encoder_filename = f'{self.model_name}_e.pth'
        save_decoder_filename = f'{self.model_name}_d.pth'
        save_encoder_path = os.path.join(self.save_dir, save_encoder_filename)
        save_decoder_path = os.path.join(self.save_dir, save_decoder_filename)
        net_d = getattr(self, 'decoder')
        net_e = getattr(self, 'encoder')

        if len(self.gpu) > 0 and torch.cuda.is_available():
            torch.save(net_d.module.cpu().state_dict(), save_decoder_path)
            net_d.cuda(self.gpu[0])
            torch.save(net_e.module.cpu().state_dict(), save_encoder_path)
            net_e.cuda(self.gpu[0])
        else:
            torch.save(net_d.cpu().state_dict(), save_decoder_path)
            torch.save(net_e.cpu().state_dict(), save_encoder_path)

    def load_networks(self):
        load_encoder_filename = f'{self.model_name}_e.pth'
        load_decoder_filename = f'{self.model_name}_d.pth'
        load_encoder_path = os.path.join(self.save_dir, load_encoder_filename)
        load_decoder_path = os.path.join(self.save_dir, load_decoder_filename)
        net_e = getattr(self, 'encoder')
        net_d = getattr(self, 'decoder')
        if isinstance(net_d, torch.nn.DataParallel):
            net_d = net_d.module
        if isinstance(net_e, torch.nn.DataParallel):
            net_e = net_e.module
        print('loading the encoder from %s' % load_encoder_path)
        print('loading the decoder from %s' % load_decoder_path)
        # if you are using PyTorch newer than 0.4 (e.g., built from
        # GitHub source), you can remove str() on self.device
        encoder_state_dict = torch.load(load_encoder_path)
        decoder_state_dict = torch.load(load_decoder_path)

        net_e.load_state_dict(encoder_state_dict)
        net_d.load_state_dict(decoder_state_dict)


    def get_current_losses(self, *loss_name):
        loss = {}
        for name in loss_name:
            loss[name] = (float(getattr(self, name)))  # float(...) works for both scalar tensor and float number
        return loss

# %%
class AAE(BaseModel):

    @staticmethod
    def add_options(parser, is_train=True):
        parser.set_defaults(no_dropout=True)
        return parser

    def __init__(self, opt):
        """Initialize the CAE model"""
        BaseModel.__init__(self, opt)
        self.opt = opt
        img_size = (self.opt.channels, self.opt.img_size, self.opt.img_size)
        latent = self.opt.latent
        self.encoder = init_net(Encoder_aae(latent).cuda(), gpu = opt.gpu, mode = opt.mode)
        # initialize encoder networks doing data parallel and init_weights
        self.decoder = init_net(Decoder(img_size, latent).cuda(), gpu = opt.gpu, mode = opt.mode)
        # initialize decoder networks doing data parallel and init_weights
        self.discriminator = init_net(Discriminator(latent).cuda(), gpu=opt.gpu, mode=opt.mode)
        # initialize discriminator networks doing data parallel and init_weights
        self.networks = ['encoder', 'decoder', 'discriminator']
        self.criterion = torch.nn.MSELoss()
        self.criterion_dm = torch.nn.BCELoss()
        self.visual_names = ['generated_imgs']
        self.model_name = self.opt.model
        self.loss_name = ['recon_loss', 'dm_loss', 'g_loss']
        self.real_label = torch.ones([self.opt.batch_size, 1])
        self.fake_label = torch.zeros([self.opt.batch_size, 1])
        if self.opt.mode == 'train':# if mode is train, we have to set optimizer and requires grad is true
            self.optimizer_e = torch.optim.Adam(self.encoder.parameters(), lr=self.opt.lr,
                                                betas=(self.opt.beta1, self.opt.beta2))
            self.optimizer_d = torch.optim.Adam(self.decoder.parameters(), lr=self.opt.lr,
                                                betas=(self.opt.beta1, self.opt.beta2))
            self.optimizer_dm = torch.optim.Adam(self.discriminator.parameters(), lr=self.opt.lr/5,
                                                betas=(self.opt.beta1, self.opt.beta2))
            self.optimizers.append(self.optimizer_e)
            self.optimizers.append(self.optimizer_d)
            self.optimizers.append(self.optimizer_dm)
            self.set_requires_grad(self.decoder, self.encoder, self.discriminator, requires_grad=True)

    def forward_recon(self):
        z = self.encoder(self.real_imgs)
        self.generated_imgs = self.decoder(z)

    def forward_dm(self):
        z_fake = self.encoder(self.real_imgs)
        self.fake = self.discriminator(z_fake)
        z_real_gauss = torch.randn(self.real_imgs.size()[0], self.opt.latent)
        self.real = self.discriminator(z_real_gauss)

        self.real_label = self.real_label.type_as(self.real)
        self.fake_label = self.fake_label.type_as(self.fake)

    def backward_recon(self):
        self.encoder.train()
        self.decoder.train()
        self.discriminator.eval()
        self.recon_loss = self.criterion(10.*self.real_imgs, 10.*self.generated_imgs)
        self.recon_loss.backward()

    def backward_dm(self):
        # discriminator train
        self.encoder.eval()
        self.decoder.eval()
        self.discriminator.train()
        self.dm_loss = self.criterion_dm(self.real, self.real_label) + self.criterion_dm(self.fake, self.fake_label)
        print("dm_loss: ", self.dm_loss)
        self.dm_loss.backward()

    def backward_g(self):
        # generator train
        self.encoder.train()
        self.discriminator.eval()
        self.fake = self.discriminator(self.encoder(self.real_imgs))
        self.g_loss = self.criterion_dm(self.fake, self.real_label)
        self.g_loss.backward()

    def set_input(self, input):
        self.real_imgs = input.to(self.device)

    def train(self):
        # recon train
        self.forward_recon()
        self.optimizer_d.zero_grad()
        self.optimizer_e.zero_grad()
        self.backward_recon()
        self.optimizer_d.step()
        self.optimizer_e.step()

        # discriminator train
        self.forward_dm()
        self.optimizer_dm.zero_grad()
        self.backward_dm()
        self.optimizer_dm.step()

        # generator train
        self.optimizer_d.zero_grad()
        self.backward_g()
        self.optimizer_d.step()

    def test(self):
        with torch.no_grad():
            self.forward_recon()

    def save_images(self, data):
        images = data['img']
        paths = os.path.join(self.opt.save_dir, self.opt.object)
        paths = os.path.join(paths, "result")
        anomaly_img = utils.compare_images(images, self.generated_imgs, threshold=self.opt.threshold)
        utils.save_images(anomaly_img, paths, data)

# %% [markdown]
# ### Opts

# %%
class Opt:
    data_dir: str = "../student_db"
    channels:int = 3
    img_size: int = 256
    gpu: list[int] = [0]
    model: str = "aae"
    save_dir: str = "/data/aae"
    latent: int = 100
    init_type: str = "normal" # [normal | xavier | kaiming | orthogonal]
    init_gain: float = 0.02
    cropsize: int = 256
    verbose:bool=True

    # train options
    print_epoch_freq: int = 1
    save_epoch_freq: int = 50
    epoch_count: int = 0
    n_epochs: int = 1000
    n_epochs_decay: int = 500
    beta1: float = 0.5
    beta2: float = 0.999
    lr: float = 0.00002
    lr_policy: str = "linear" # [linear | step | plateau | cosine]
    lr_decay_iters: int = 50
    batch_size: int = 8
    mode: str = "train"
    num_threads:int = 10
    no_dropout: bool = True
    rotate: bool = False
    brightness:float=  0.1
    object:str = "notrash"

opt = Opt()

# %% [markdown]
# ### Train
# #### load dataset

# %%
def get_transform(opt):
    """Transforms images"""
    transform = []
    if opt.rotate == True:
        transform.append(T.RandomRotation(0.5))
    transform.append(T.ColorJitter(brightness=opt.brightness))
    transform.append(T.Resize((opt.cropsize, opt.cropsize), interpolation=2))
    transform.append(T.ToTensor())
    if opt.channels == 3:
        transform.append(T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)))
    elif opt.channels == 1:
        transform.append(T.Normalize((0.5), (0.5)))

    return T.Compose(transform)

# %%
class CustomDatasetDataLoader():
    """Wrapper class of Dataset class that performs multi-threaded data loading"""

    def __init__(self, opt, dataset):
        """Create a dataset instance given the name [dataset_mode] and a multi-threaded data loader."""
        self.opt = opt
        self.dataset = dataset
        self.dataloader = torch.utils.data.DataLoader(
            self.dataset,
            batch_size=opt.batch_size,
            num_workers=int(opt.num_threads),
            drop_last=True)

    def load_data(self):
        return self

    def __len__(self):
        """Return the number of data in the dataset"""
        return len(self.dataset)

    def __iter__(self):
        """Return a batch of data"""
        for i, data in enumerate(self.dataloader):
            # if i * self.opt.batch_size >= self.opt.max_dataset_size:
            #     break
            yield data

# %%
dataset = TrashDataset("../student_db", train=get_transform(opt), grayscale=False)
dataset_size = len(dataset)
data_loader = CustomDatasetDataLoader(opt, dataset)
dataset = data_loader.load_data()
print(f"Training size is = {dataset_size}")
# Out:
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=10)]: Done   6 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=10)]: Done  16 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=10)]: Done 520 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=10)]: Done 1220 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=10)]: Done 2120 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=10)]: Done 3020 tasks      | elapsed:   15.4s
# [Parallel(n_jobs=10)]: Done 4120 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=10)]: Done 5220 tasks      | elapsed:   21.2s
# [Parallel(n_jobs=10)]: Done 6520 tasks      | elapsed:   25.0s
# [Parallel(n_jobs=10)]: Done 7820 tasks      | elapsed:   29.9s
# [Parallel(n_jobs=10)]: Done 9320 tasks      | elapsed:   33.9s
# [Parallel(n_jobs=10)]: Done 10820 tasks      | elapsed:   38.0s
# [Parallel(n_jobs=10)]: Done 12520 tasks      | elapsed:   42.5s
# [Parallel(n_jobs=10)]: Done 14220 tasks      | elapsed:   47.2s
# [Parallel(n_jobs=10)]: Done 16120 tasks      | elapsed:   52.3s
# [Parallel(n_jobs=10)]: Done 18020 tasks      | elapsed:   57.7s
# [Parallel(n_jobs=10)]: Done 20120 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=10)]: Done 22220 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=10)]: Done 24520 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=10)]: Done 26820 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=10)]: Done 29320 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=10)]: Done 31820 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=10)]: Done 34520 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=10)]: Done 37220 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=10)]: Done 39108 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=10)]: Done 39340 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=10)]: Done 39588 tasks      | elapsed:  2.1min
# Training size is = 39900
# [Parallel(n_jobs=10)]: Done 39900 out of 39900 | elapsed:  2.1min finished

# %% [markdown]
# #### load model

# %%
model = AAE(opt)       # create model (AE, AAE)
model.setup(opt)   
total_iters = 0
loss_name = model.loss_name            # loss name for naming
# Out:
# initialize network with normal
# initialize network with normal
# initialize network with normal
# ---------- Networks initialized -------------
# DataParallel(
#   (module): Encoder_aae(
#     (model): Sequential(
#       (0): Conv2d(3, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): InstanceNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (2): LeakyReLU(negative_slope=0.2, inplace=True)
#       (3): Conv2d(16, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (4): InstanceNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (5): LeakyReLU(negative_slope=0.2, inplace=True)
#       (6): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (7): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (8): LeakyReLU(negative_slope=0.2, inplace=True)
#       (9): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (10): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (11): LeakyReLU(negative_slope=0.2, inplace=True)
#       (12): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (13): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (14): LeakyReLU(negative_slope=0.2, inplace=True)
#       (15): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (16): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#       (17): LeakyReLU(negative_slope=0.2, inplace=True)
#       (18): Conv2d(512, 1024, kernel_size=(4, 4), stride=(1, 1))
#     )
#     (last_layer): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#     )
#     (mu_layer): Linear(in_features=512, out_features=100, bias=True)
#     (std_layer): Linear(in_features=512, out_features=100, bias=True)
#   )
# )
# [Network encoder] Total number of parameters : 11.814 M
# DataParallel(
#   (module): Decoder(
#     (model): Sequential(
#       (0): ConvTranspose2d(100, 1024, kernel_size=(4, 4), stride=(1, 1))
#       (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=True)
#       (3): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): LeakyReLU(negative_slope=True)
#       (6): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (8): LeakyReLU(negative_slope=True)
#       (9): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (10): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (11): LeakyReLU(negative_slope=True)
#       (12): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): LeakyReLU(negative_slope=True)
#       (15): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (16): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (17): LeakyReLU(negative_slope=True)
#       (18): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (19): Tanh()
#     )
#   )
# )
# [Network decoder] Total number of parameters : 12.820 M
# DataParallel(
#   (module): Discriminator(
#     (model): Sequential(
#       (0): Linear(in_features=100, out_features=100, bias=True)
#       (1): Linear(in_features=100, out_features=1, bias=True)
#       (2): Sigmoid()
#     )
#   )
# )
# [Network discriminator] Total number of parameters : 0.010 M
# -----------------------------------------------

# %%
for epoch in range(opt.epoch_count, opt.n_epochs + opt.n_epochs_decay + 1):
    epoch_start_time = time.time()                      # start epoch time
    model.update_learning_rate(epoch)                   # update learning rate change with schedulers
    epoch_iters = 0

    for i, (data, _) in enumerate(dataset):                  # dataset loop
        iter_start_time = time.time()                   # start iter time
        model.set_input(data)                           # unpacking input data for processing
        model.train()                                   # start model train
        total_iters += 1
        epoch_iters += 1
    if epoch % opt.print_epoch_freq == 0:               # model loss, time print frequency
        losses = model.get_current_losses(*loss_name)
        epoch_time = time.time() - epoch_start_time
        message = f"epoch : {epoch} | total_iters : {total_iters} | epoch_time:{epoch_time:.3f}"
        for k,v in losses.items():
            message += f" | {k}:{v}"
        print(message)
    if epoch % opt.save_epoch_freq == 0:                # save model frequency
        print(
            "saving the latest model (epoch %d, total_iters %d)"
            % (epoch, total_iters)
        )
        model.save_networks()
        utils.plt_show(model.generated_imgs[:3])
# Out:
# dm_loss:  tensor(0.2323, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2431, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2225, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2104, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2006, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2492, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2323, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2094, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2426, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2014, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1964, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2193, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2336, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2400, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2334, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2442, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2414, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2565, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2024, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2275, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2084, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2108, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2505, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2513, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2400, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2181, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2226, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2320, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2260, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2301, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2280, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1991, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2614, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1941, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2068, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2226, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2448, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2490, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1979, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2170, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2264, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2342, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2429, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2493, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2084, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2242, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2362, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2339, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2302, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2711, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2630, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2152, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2281, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2375, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2083, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2290, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1975, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2005, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2267, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2202, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2125, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2238, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2230, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.3144, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2312, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1673, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2385, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2103, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2648, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2176, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2165, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2169, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2175, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2327, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.3026, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2107, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2820, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2053, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2159, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2029, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2189, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2394, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2847, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2198, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2209, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2019, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2400, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2258, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2902, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2410, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2382, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2041, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2179, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2038, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2210, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2157, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2028, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2548, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2516, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2389, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2560, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2464, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2306, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2434, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1986, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2691, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2307, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2694, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2450, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1723, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2086, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2430, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2168, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1867, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2813, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2256, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2215, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2076, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2582, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2376, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2177, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2285, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2248, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2177, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2342, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2343, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2256, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2315, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2151, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1990, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2441, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2752, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2272, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2109, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2332, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2322, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2453, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2330, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2419, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2204, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2174, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2179, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2118, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2218, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2043, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2347, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1954, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2438, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2240, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2112, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2306, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2111, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2129, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2182, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2429, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2177, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2520, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2337, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2033, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2462, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2247, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2315, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2378, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2265, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2560, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2486, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2558, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1671, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2066, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1795, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2140, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2461, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2190, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2014, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2401, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2057, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2629, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2740, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2224, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1948, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2479, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2218, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2504, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2714, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2429, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2539, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2572, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2149, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2139, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2079, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2078, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2281, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2231, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2325, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2151, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2308, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2150, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2498, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2092, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2107, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1921, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2218, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2436, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1920, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2465, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1956, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2449, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2453, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2277, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1927, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2092, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2376, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1909, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2065, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2162, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2122, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2111, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2466, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2183, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2569, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2265, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2170, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2205, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2497, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2323, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2485, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1979, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2542, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2038, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2716, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2250, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2241, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2804, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2340, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2101, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2154, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2146, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2426, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2322, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2269, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1908, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2195, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2236, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1995, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2245, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2213, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1843, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1998, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2287, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2185, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2364, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2259, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2421, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1823, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2276, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2405, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2086, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2424, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2108, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2006, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2300, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2320, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2126, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2130, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2446, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1927, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2188, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1865, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1827, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2206, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2241, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2321, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2171, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2397, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2108, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2413, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2070, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2382, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2343, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1713, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2084, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2382, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2014, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1956, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1702, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1871, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2540, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2640, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2450, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2475, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2255, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2220, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2051, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2786, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2322, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1951, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1770, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2081, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2372, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1875, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2577, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2749, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2312, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2138, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2258, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2444, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2313, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2326, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2359, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2385, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2252, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2195, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1820, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2491, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2254, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2168, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1808, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1958, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2168, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2070, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1998, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2075, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2173, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2118, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2290, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2403, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1675, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2344, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2321, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2345, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2239, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2173, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1895, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1867, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1957, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1922, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2272, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2235, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2152, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1828, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2675, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2365, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1810, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2204, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2242, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2075, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2013, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2438, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2476, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1971, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2391, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2380, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2116, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2485, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2295, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1968, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2280, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2253, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2438, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2580, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2605, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2056, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1992, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2526, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2320, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1955, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2080, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1854, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2166, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2159, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2445, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2350, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1675, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2377, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2336, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2671, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2376, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1924, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1833, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2023, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2171, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2243, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2183, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2322, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2158, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2448, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2525, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2473, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2488, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1693, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1707, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1984, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2140, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2312, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1837, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2582, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2340, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2262, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2334, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2013, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1835, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2409, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1894, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1963, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2320, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2024, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2441, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1997, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2207, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2258, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2427, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2478, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2153, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2397, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2555, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2167, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2111, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2378, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2139, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2639, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2453, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2266, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1916, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2423, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1856, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1929, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2216, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2199, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2244, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2341, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2371, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2644, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1943, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2177, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2046, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2387, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2293, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2108, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2174, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2121, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2178, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2149, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2413, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2426, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2421, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2356, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2159, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1706, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2042, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2211, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2220, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2528, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2653, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2503, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2067, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2113, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2109, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2264, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2581, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2320, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2451, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2678, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2129, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2183, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2202, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2137, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2181, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2540, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2280, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2232, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1902, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2175, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2005, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2311, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2447, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2296, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2161, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2402, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2259, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1947, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2036, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2323, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2255, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2172, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1993, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2147, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2223, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2297, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2341, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1914, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1940, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2238, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2490, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1828, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2313, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1961, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2192, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2107, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2009, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2141, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2231, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1830, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2017, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2202, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2046, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2347, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2177, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2260, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2015, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2329, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1973, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2075, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2079, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2236, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2000, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2008, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2356, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2131, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2029, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2305, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2264, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2303, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2479, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2259, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2774, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1838, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2127, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2210, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2200, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2063, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2334, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2486, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2106, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2244, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2165, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1970, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2101, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2353, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2147, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2201, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1955, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2024, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2399, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2147, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2385, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2263, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1740, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2628, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2489, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2322, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2130, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2404, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2516, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1877, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2546, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2240, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2072, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2115, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2248, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1991, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2077, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2276, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2292, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2491, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2240, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2182, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2079, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2152, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2086, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2085, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2246, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1969, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2380, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2103, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2089, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2163, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1999, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2471, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2097, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1877, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2188, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2601, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2211, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2316, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2095, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2268, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2622, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2327, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2040, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2401, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2485, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2619, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2514, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2163, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2303, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2089, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2861, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2121, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2240, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2099, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1908, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1988, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2216, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2217, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2087, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1930, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2152, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1962, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2304, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2238, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1945, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2250, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2231, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2383, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2640, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1889, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2266, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2246, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2318, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2119, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2100, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1915, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2392, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2336, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2093, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2197, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2257, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2189, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2510, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2274, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2118, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2269, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1966, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2383, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2147, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2110, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2191, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2185, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2205, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1938, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2087, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2044, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1823, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1696, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1653, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2547, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2158, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2358, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2348, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2238, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1932, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2540, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2227, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2539, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2240, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2034, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1941, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2132, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2694, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2130, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2555, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1976, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2048, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1987, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2463, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2222, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2072, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2213, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1724, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2081, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2106, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2194, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2214, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2249, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2258, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2202, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2347, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2230, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2171, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2206, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2569, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2604, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1966, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1936, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2203, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2095, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1937, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2192, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2437, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1994, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2688, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2141, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1911, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2090, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2389, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2154, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2198, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2275, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2199, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1998, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2171, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2235, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1933, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2181, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2125, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2247, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1918, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2296, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1885, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1986, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2080, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2394, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1804, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2449, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1892, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2140, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2005, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1898, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2218, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2322, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.1939, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.2034, device='cuda:0', grad_fn=<AddBackward0>)
# ...
# dm_loss:  tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0073, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0072, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0069, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0077, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0067, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0087, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0075, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0071, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0069, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0067, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0063, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0063, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0070, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0073, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0065, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0063, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0070, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0081, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0068, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0042, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0044, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0068, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0064, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0044, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0044, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0066, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0063, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0063, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0063, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0063, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0071, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0062, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0060, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0044, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0045, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0073, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0069, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0044, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0047, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0072, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0051, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0050, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0061, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0057, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0049, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0059, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0052, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0056, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0058, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0053, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0046, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0081, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0067, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0063, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0055, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0048, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0043, device='cuda:0', grad_fn=<AddBackward0>)
# dm_loss:  tensor(0.0054, device='cuda:0', grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 9
#       7 iter_start_time = time.time()                   # start iter time
#       8 model.set_input(data)                           # unpacking input data for processing
# ----> 9 model.train()                                   # start model train
#      10 total_iters += 1
#      11 epoch_iters += 1
#
# Cell In[6], line 85, in AAE.train(self)
#      83 self.optimizer_d.zero_grad()
#      84 self.optimizer_e.zero_grad()
# ---> 85 self.backward_recon()
#      86 self.optimizer_d.step()
#      87 self.optimizer_e.step()
#
# Cell In[6], line 58, in AAE.backward_recon(self)
#      56 self.discriminator.eval()
#      57 self.recon_loss = self.criterion(10.*self.real_imgs, 10.*self.generated_imgs)
# ---> 58 self.recon_loss.backward()
#
# File ~/AD-VAE/venv/lib/python3.10/site-packages/torch/_tensor.py:487, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     477 if has_torch_function_unary(self):
#     478     return handle_torch_function(
#     479         Tensor.backward,
#     480         (self,),
#    (...)
#     485         inputs=inputs,
#     486     )
# --> 487 torch.autograd.backward(
#     488     self, gradient, retain_graph, create_graph, inputs=inputs
#     489 )
#
# File ~/AD-VAE/venv/lib/python3.10/site-packages/torch/autograd/__init__.py:200, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     195     retain_graph = create_graph
#     197 # The reason we repeat same the comment below is that
#     198 # some Python versions print out the first line of a multi-line function
#     199 # calls in the traceback and some print out the last line
# --> 200 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     201     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     202     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:
